# %%
import pandas as pd
import networkx as nx

# Read in the contract data from a CSV file
df1 = pd.read_csv('C:\\Users\\Lenovo\\OneDrive\\文档\\CCL 2023\\Business with HRSA Contracts 2019-2023.csv')
df2=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\文档\\CCL 2023\\Business with CFPB Contracts.csv")
df3=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\文档\\CCL 2023\\Business with IRS Contracts.csv")
df=pd.concat([df1,df2,df3],axis=0)


# Create a new dataframe to store the company and agency relationships
relationship_data = pd.DataFrame(columns=['Company','Agency', 'Contracts'])

# %%
# Loop through each contract and extract the company and agency information
for index, row in df.iterrows():
    company = row['Legal Business Name']
    agency = row['Contracting Office Name']
    contracts = row['Action Obligation ($)']
    
    # Check if the company and agency already have a relationship in the dataframe
    existing_relationship = relationship_data.loc[(relationship_data['Company'] == company) & (relationship_data['Agency'] == agency)]
    
    # If the relationship already exists, update the contract count and total value
    if not existing_relationship.empty:
        relationship_data.loc[(relationship_data['Company'] == company) & (relationship_data['Agency'] == agency), 'Contracts'] += 1
        relationship_data.loc[(relationship_data['Company'] == company) & (relationship_data['Agency'] == agency), 'Total Value'] += contracts
    
    # If the relationship doesn't exist yet, create a new row in the dataframe
    else:
        new_row = {'Company': company, 'Agency': agency, 'Contracts': 1, 'Total Value': contracts}
        relationship_data = relationship_data.append(new_row, ignore_index=True)
    
# Create a new graph using networkx
G = nx.Graph()

# Add the company and agency nodes to the graph
for company in relationship_data['Company'].unique():
    G.add_node(company, node_type='company',name=company)
    
for agency in relationship_data['Agency'].unique():
    G.add_node(agency, node_type='agency',name=agency)

# Add the edges to the graph
for index, row in relationship_data.iterrows():
    company = row['Company']
    agency = row['Agency']
    contracts = row['Contracts']
    
    G.add_edge(company, agency, weight=contracts)

# %%
#Identify the offices have relationship to certain company

node_of_interest = 'NORTHROP GRUMMAN SPACE AND MISSION SYSTEMS CORPORATION'

neighbors = list(G.neighbors(node_of_interest))
print(f"The neighbors of {node_of_interest} are: {neighbors}")
# Out:
# The neighbors of NORTHROP GRUMMAN SPACE AND MISSION SYSTEMS CORPORATION are: ['BUREAU OF HEALTH PROFESSSIONS', 'OFFICE OF THE ADMINISTRATOR']

# %%
#Identify the connection between company and certain office

company='JEFF MURRAY\'S PROGRAMMING SHOP'
neighbors = G.neighbors(company)
print(f"For {company}")
for neighbor in neighbors:
    print(f"Neighbor: {neighbor}")
    edge_weight = G[company][neighbor]['weight']
    print(f"Connection Score:{edge_weight} out of 113")
    print('----')
# Out:
# For JEFF MURRAY'S PROGRAMMING SHOP
# Neighbor: OFFICE OF THE ADMINISTRATOR
# Connection Score:28 out of 113
# ----
# Neighbor: HRSA HEADQUARTERS
# Connection Score:13 out of 113
# ----

# %%
company='HRSA HEADQUARTERS'
neighbors = G.neighbors(company)
print(f"For{company}")
for neighbor in neighbors:
    print(f"Neighbor: {neighbor}")
    edge_weight = G[company][neighbor]['weight']
    print(f"Connection Score:{edge_weight} out of 113")
    print('----')
# Out:
# ForHRSA HEADQUARTERS
# Neighbor: SAPIENT GOVERNMENT SERVICES, INC.
# Connection Score:113 out of 113
# ----
# Neighbor: ARCH SYSTEMS LLC
# Connection Score:8 out of 113
# ----
# Neighbor: BOOZ ALLEN HAMILTON INC.
# Connection Score:7 out of 113
# ----
# Neighbor: QUETEL CORPORATION
# Connection Score:1 out of 113
# ----
# Neighbor: SOLE SOLUTIONS INC.
# Connection Score:8 out of 113
# ----
# Neighbor: ACTIVEPDF INC
# Connection Score:1 out of 113
# ----
# Neighbor: KRM ASSOCIATES, INC
# Connection Score:2 out of 113
# ----
# Neighbor: SUPRIYA AGGARWAL
# Connection Score:10 out of 113
# ----
# Neighbor: JEFF MURRAY'S PROGRAMMING SHOP
# Connection Score:13 out of 113
# ----
# Neighbor: IMMERSIVE CONCEPTS, LLC
# Connection Score:4 out of 113
# ----
# Neighbor: SCIENTIFIC SYSTEMS AND SOFTWARE INTERNATIONAL CORPORATION
# Connection Score:4 out of 113
# ----
# Neighbor: AQUILENT, INC
# Connection Score:6 out of 113
# ----
# Neighbor: SHABAS SOLUTIONS, LLC
# Connection Score:6 out of 113
# ----
# Neighbor: SPROUT SOCIAL, INC.
# Connection Score:3 out of 113
# ----
# Neighbor: NORTHROP GRUMMAN INFORMATION TECHNOLOGY GLOBAL CORPORATION
# Connection Score:1 out of 113
# ----
# Neighbor: SOFTWARE ARTISANS, INC.
# Connection Score:4 out of 113
# ----
# Neighbor: CORE BTS, INC.
# Connection Score:1 out of 113
# ----
# Neighbor: LOGICAL CONSULTING GROUP INC
# Connection Score:1 out of 113
# ----
# Neighbor: AVEPOINT PUBLIC SECTOR, INC.
# Connection Score:1 out of 113
# ----
# Neighbor: GO TO GROUP, INC, THE
# Connection Score:2 out of 113
# ----
# Neighbor: SENET INTERNATIONAL CORPORATIO
# Connection Score:1 out of 113
# ----
# Neighbor: INTERACTIVE COMMUNICATIONS SOLUTIONS GROUP, INC.
# Connection Score:7 out of 113
# ----
# Neighbor: VINSYS INFORMATION TECHNOLOGY, INC
# Connection Score:1 out of 113
# ----
# Neighbor: WESTAT, INC.
# Connection Score:1 out of 113
# ----
# Neighbor: NETWORK MANAGEMENT RESOURCES
# Connection Score:3 out of 113
# ----
# Neighbor: I-LINK SOLUTIONS, INC
# Connection Score:1 out of 113
# ----
# Neighbor: COMPULINK MANAGEMENT CENTER, INC.
# Connection Score:1 out of 113
# ----
# Neighbor: EDAPTIVE SYSTEMS, L.L.C.
# Connection Score:1 out of 113
# ----
# Neighbor: FUTREND TECHNOLOGY INC
# Connection Score:1 out of 113
# ----
# Neighbor: WORD WIZARDS INC
# Connection Score:1 out of 113
# ----
# Neighbor: SWISH DATA CORPORATION
# Connection Score:1 out of 113
# ----
# Neighbor: GLOBAL COMMERCE & INFORMATION, INC.
# Connection Score:1 out of 113
# ----
# Neighbor: H3 SOLUTIONS INCORPORATED
# Connection Score:1 out of 113
# ----
# Neighbor: DIGICON CORPORATION
# Connection Score:1 out of 113
# ----
# Neighbor: PLEXUS SCIENTIFIC CORPORATION
# Connection Score:1 out of 113
# ----
# Neighbor: ISSUETRAK INC
# Connection Score:1 out of 113
# ----

# %%
#The full list of connections
for source, target, weight in G.edges(data='weight'):
    print(f"{source} -> {target}: {weight}")
# Out:
# NORTHROP GRUMMAN SPACE AND MISSION SYSTEMS CORPORATION -> BUREAU OF HEALTH PROFESSSIONS: 5
# NORTHROP GRUMMAN SPACE AND MISSION SYSTEMS CORPORATION -> OFFICE OF THE ADMINISTRATOR: 8
# PRIMESCAPE SOLITIONS INC -> OFFICE OF THE ADMINISTRATOR: 45
# SAPIENT GOVERNMENT SERVICES, INC. -> HRSA HEADQUARTERS: 113
# SAPIENT GOVERNMENT SERVICES, INC. -> OFFICE OF THE ADMINISTRATOR: 6
# ARCH SYSTEMS LLC -> HRSA HEADQUARTERS: 8
# BOOZ ALLEN HAMILTON INC. -> HRSA HEADQUARTERS: 7
# LUX CONSULTING GROUP -> OFFICE OF THE ADMINISTRATOR: 5
# LUX CONSULTING GROUP -> BUREAU OF HEALTH PROFESSSIONS: 1
# LUX CONSULTING GROUP, INC. -> OFFICE OF THE ADMINISTRATOR: 10
# MILLENNIUM SERVICES 2000+ INCORPORATED -> OFFICE OF THE ADMINISTRATOR: 5
# MINDFINDERS INCORPORATED -> OFFICE OF THE ADMINISTRATOR: 17
# ACCESS SYSTEMS INCORPORATED -> OFFICE OF THE ADMINISTRATOR: 5
# ACCESS SYSTEMS INCORPORATED -> BUREAU OF HEALTH PROFESSSIONS: 1
# NORTHROP GRUMMAN INFORMATION T -> OFFICE OF THE ADMINISTRATOR: 4
# NORTHROP GRUMMAN INFORMATION TECHNOLOGY GLOBAL CORPORATION -> OFFICE OF THE ADMINISTRATOR: 11
# NORTHROP GRUMMAN INFORMATION TECHNOLOGY GLOBAL CORPORATION -> HRSA HEADQUARTERS: 1
# TRI-COR INDUSTRIES, INC -> OFFICE OF THE ADMINISTRATOR: 12
# NOVA RESEARCH COMPANY -> OFFICE OF THE ADMINISTRATOR: 10
# JEFF MURRAY'S PROGRAMMING SHOP -> OFFICE OF THE ADMINISTRATOR: 28
# JEFF MURRAY'S PROGRAMMING SHOP -> HRSA HEADQUARTERS: 13
# QUETEL CORPORATION -> HRSA HEADQUARTERS: 1
# QUETEL CORPORATION -> OFFICE OF THE ADMINISTRATOR: 1
# SOLE SOLUTIONS INC. -> HRSA HEADQUARTERS: 8
# SOLE SOLUTIONS INC. -> OFFICE OF THE ADMINISTRATOR: 35
# ACTIVEPDF INC -> HRSA HEADQUARTERS: 1
# ACTIVEPDF INC -> OFFICE OF THE ADMINISTRATOR: 1
# GROVE RESOURCE SOLUTIONS, INC. -> OFFICE OF THE ADMINISTRATOR: 5
# DSFEDERAL, INC. -> OFFICE OF THE ADMINISTRATOR: 6
# LOGICAL CONSULTING GROUP INC -> OFFICE OF THE ADMINISTRATOR: 4
# LOGICAL CONSULTING GROUP INC -> HRSA HEADQUARTERS: 1
# NETWORK MANAGEMENT RESOURCES -> OFFICE OF THE ADMINISTRATOR: 33
# NETWORK MANAGEMENT RESOURCES -> HRSA HEADQUARTERS: 3
# KRM ASSOCIATES, INC -> HRSA HEADQUARTERS: 2
# KRM ASSOCIATES, INC -> OFFICE OF THE ADMINISTRATOR: 5
# KBTS TECHNOLOGIES, INC -> OFFICE OF THE ADMINISTRATOR: 3
# CORE BTS, INC. -> OFFICE OF THE ADMINISTRATOR: 9
# CORE BTS, INC. -> HRSA HEADQUARTERS: 1
# H3 SOLUTIONS INCORPORATED -> OFFICE OF THE ADMINISTRATOR: 1
# H3 SOLUTIONS INCORPORATED -> HRSA HEADQUARTERS: 1
# SOFTWARE ARTISANS, INC. -> OFFICE OF THE ADMINISTRATOR: 7
# SOFTWARE ARTISANS, INC. -> HRSA HEADQUARTERS: 4
# EDAPTIVE SYSTEMS, L.L.C. -> OFFICE OF THE ADMINISTRATOR: 11
# EDAPTIVE SYSTEMS, L.L.C. -> HRSA HEADQUARTERS: 1
# SUPRIYA AGGARWAL -> OFFICE OF THE ADMINISTRATOR: 12
# SUPRIYA AGGARWAL -> HRSA HEADQUARTERS: 10
# NET.AMERICA CORPORATION, THE -> OFFICE OF THE ADMINISTRATOR: 2
# ISSUETRAK INC -> OFFICE OF THE ADMINISTRATOR: 8
# ISSUETRAK INC -> HRSA HEADQUARTERS: 1
# FUTREND TECHNOLOGY INC -> OFFICE OF THE ADMINISTRATOR: 2
# FUTREND TECHNOLOGY INC -> HRSA HEADQUARTERS: 1
# IMMERSIVE CONCEPTS, LLC -> HRSA HEADQUARTERS: 4
# IMMERSIVE CONCEPTS, LLC -> OFFICE OF THE ADMINISTRATOR: 3
# SCIENTIFIC SYSTEMS AND SOFTWARE INTERNATIONAL CORPORATION -> OFFICE OF THE ADMINISTRATOR: 1
# SCIENTIFIC SYSTEMS AND SOFTWARE INTERNATIONAL CORPORATION -> HRSA HEADQUARTERS: 4
# AQUILENT, INC -> HRSA HEADQUARTERS: 6
# SHABAS SOLUTIONS, LLC -> HRSA HEADQUARTERS: 6
# SHABAS SOLUTIONS, LLC -> OFFICE OF THE ADMINISTRATOR: 3
# KEARNEY, MICHAEL -> NATIONAL HANSENS DISEASE PROGRAM: 2
# KEARNEY, MICHAEL -> DEPT OF HHS/HEALTH RESOURCES AND SVCS ADMIN: 7
# BAE SYSTEMS PORTAL SOLUTIONS I -> BUREAU OF PRIMARY HEALTH CARE: 1
# PRIMESCAPE SOLUTIONS, INC. -> BUREAU OF PRIMARY HEALTH CARE: 2
# PRIMESCAPE SOLUTIONS, INC. -> OFFICE OF THE ADMINISTRATOR: 2
# METRIX TECHNOLOGIES, INC -> OFFICE OF THE ADMINISTRATOR: 8
# METRIX TECHNOLOGIES, INC -> BUREAU OF HEALTH PROFESSSIONS: 5
# SPROUT SOCIAL, INC. -> HRSA HEADQUARTERS: 3
# CLIENT/SERVER SOFTWARE SOLUTIO -> OFFICE OF THE ADMINISTRATOR: 4
# SOFTWARE ARTISANS INCORPORATED -> OFFICE OF THE ADMINISTRATOR: 1
# MICROLINK, L.L.C. -> OFFICE OF THE ADMINISTRATOR: 11
# HOSTED RECORDS INC. -> OFFICE OF THE ADMINISTRATOR: 2
# AVEPOINT PUBLIC SECTOR, INC. -> HRSA HEADQUARTERS: 1
# AVEPOINT PUBLIC SECTOR, INC. -> OFFICE OF THE ADMINISTRATOR: 3
# NET 2000 LTD -> OFFICE OF THE ADMINISTRATOR: 2
# GO TO GROUP, INC, THE -> HRSA HEADQUARTERS: 2
# PRIMESCAPE SOLUTIONS INC. -> OFFICE OF THE ADMINISTRATOR: 15
# KEARNEY MICHAEL -> DEPT OF HHS/HEALTH RESOURCES AND SVCS ADMIN: 1
# NORTHRUP GRUMMAN COMPUTING SYSTEMS, INC. -> OFFICE OF THE ADMINISTRATOR: 2
# WORD WIZARDS INC -> OFFICE OF THE ADMINISTRATOR: 2
# WORD WIZARDS INC -> HRSA HEADQUARTERS: 1
# SENET INTERNATIONAL CORPORATIO -> OFFICE OF THE ADMINISTRATOR: 2
# SENET INTERNATIONAL CORPORATIO -> HRSA HEADQUARTERS: 1
# SWISH DATA CORPORATION -> OFFICE OF THE ADMINISTRATOR: 3
# SWISH DATA CORPORATION -> HRSA HEADQUARTERS: 1
# EVERGREEN SYSTEMS, INC. -> OFFICE OF THE ADMINISTRATOR: 2
# CONSOLIDATED SAFETY SERVICES INCORPORATED -> OFFICE OF THE ADMINISTRATOR: 1
# REDION LIMITED LIABILITY COMPANY -> DEPT OF HHS/HEALTH RESOURCES AND SVCS ADMIN: 1
# INTERACTIVE COMMUNICATIONS SOLUTIONS GROUP, INC. -> HRSA HEADQUARTERS: 7
# VINSYS INFORMATION TECHNOLOGY, INC -> HRSA HEADQUARTERS: 1
# COMPULINK MANAGEMENT CENTER, INC. -> OFFICE OF THE ADMINISTRATOR: 2
# COMPULINK MANAGEMENT CENTER, INC. -> HRSA HEADQUARTERS: 1
# WESTAT, INC. -> OFFICE OF THE ADMINISTRATOR: 4
# WESTAT, INC. -> HRSA HEADQUARTERS: 1
# I-LINK SOLUTIONS, INC -> HRSA HEADQUARTERS: 1
# INFORMATION ANALYSIS INCORPORATED -> OFFICE OF THE ADMINISTRATOR: 1
# WT CHEN & COMPANY, INC. -> OFFICE OF THE ADMINISTRATOR: 1
# APLUS TECHNOLOGIES -> OFFICE OF THE ADMINISTRATOR: 2
# ACUMEN, LLC -> BUREAU OF HEALTH RESOURCES DEVELOPMENT: 1
# GLOBAL COMMERCE & INFORMATION, INC. -> HRSA HEADQUARTERS: 1
# KOREM CORPORATION -> OFFICE OF THE ADMINISTRATOR: 1
# DIGICON CORPORATION -> OFFICE OF THE ADMINISTRATOR: 1
# DIGICON CORPORATION -> HRSA HEADQUARTERS: 1
# NORTHROP GRUMMAN COMPUTING SYS -> OFFICE OF THE ADMINISTRATOR: 1
# CONSOLIDATED SAFETY SERVICES, INC. -> OFFICE OF THE ADMINISTRATOR: 1
# COMPUTER TECHNOLOGY SERVICES INCORPORATED -> BUREAU OF HEALTH PROFESSSIONS: 1
# IDEA INTEGRATION CORP -> BUREAU OF PRIMARY HEALTH CARE: 1
# PLEXUS SCIENTIFIC CORPORATION -> HRSA HEADQUARTERS: 1
# COMMUNICATIONS RESOURCE INCORPORATED -> CFPB PROCUREMENT: 4
# QUANTA SYSTEMS CORPORATION -> CFPB PROCUREMENT: 7
# CROSS MATCH TECHNOLOGIES INCORPORATED -> CFPB PROCUREMENT: 4
# INFOUSA INCORPORATED (4710) -> CFPB PROCUREMENT: 2
# CROSS MATCH TECHNOLOGIES, INC. -> CFPB PROCUREMENT: 2
# THOUGHT OBJECT LLC -> CONSUMER FINANCE PROTECTION BUREAU: 1
# POWERLYTICS, INC. -> CONSUMER FINANCE PROTECTION BUREAU: 4
# OCTO METRIC LLC -> NATIONAL OFFICE - PROCUREMENT OITA: 2
# PURISOLVE, INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 16
# PURISOLVE, INC. -> NATIONAL OFFICE - PROCUREMENT OBO: 1
# PURISOLVE, INC. -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 2
# DELMOCK TECHNOLOGIES, INC -> NATIONAL OFFICE - PROCUREMENT OITA: 2
# DELMOCK TECHNOLOGIES, INC -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 2
# CYBERMEDIA TECHNOLOGIES, INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 1
# CYBERMEDIA TECHNOLOGIES, INC. -> NATIONAL OFFICE - PROCUREMENT OBO: 1
# BLUE CANOPY GROUP, LLC -> NATIONAL OFFICE - PROCUREMENT OITA: 2
# RESTON CONSULTING GROUP, INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 3
# ECS FEDERAL, LLC -> NATIONAL OFFICE - PROCUREMENT OITA: 1
# CREATIVE SYSTEMS AND CONSULTING -> NATIONAL OFFICE - PROCUREMENT OITA: 1
# TECHNOLOGY BLUE, INC. -> NATIONAL OFFICE - PROCUREMENT OBO: 3
# TECHNOLOGY BLUE, INC. -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# ADI DATA INTERNATIONAL INC -> NATIONAL OFFICE - PROCUREMENT OITA: 11
# AI4GOVT CORPORATION. -> NATIONAL OFFICE - PROCUREMENT OITA: 4
# AI4GOVT CORPORATION. -> NATIONAL OFFICE - PROCUREMENT OBO: 1
# DRT STRATEGIES, INC. -> NATIONAL OFFICE - PROCUREMENT OBO: 1
# DRT STRATEGIES, INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 5
# ANIKA SYSTEMS INCORPORATED -> NATIONAL OFFICE - PROCUREMENT OITA: 3
# ANIKA SYSTEMS INCORPORATED -> NATIONAL OFFICE - PROCUREMENT OBO: 1
# RESILIENT SOLUTIONS 21, LLC -> NATIONAL OFFICE - PROCUREMENT OBO: 2
# RESILIENT SOLUTIONS 21, LLC -> NATIONAL OFFICE - PROCUREMENT OITA: 3
# AEON NEXUS CORPORATION -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# SYNEREN TECHNOLOGIES CORPORATION -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# MANAGEMENT TECHNOLOGY INC -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# CANTON GROUP LIMITED LIABILITY COMPANY, THE -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# SAS INSTITUTE INC. -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 2
# SAS INSTITUTE INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 2
# INTELLECT SOLUTIONS, LLC -> NATIONAL OFFICE - PROCUREMENT OITA: 9
# INTELLECT SOLUTIONS, LLC -> CHIEF INFORMATION OFFICER: 1
# DATASOURCE, INC -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 6
# 22ND CENTURY TECHNOLOGIES INC. -> SOUTHEAST REGION: 1
# VIVA USA INC. -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# INTEGRATED SOLUTIONS MANAGEMENT, INC -> NATIONAL OFFICE - PROCUREMENT OITA: 6
# EXCEED RESOURCES INC -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# SOPHAM CONSULTING GROUP, INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 2
# G-STAR TELECOM, INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 23
# THUNDERCAT TECHNOLOGY, LLC -> DEPT OF TREAS/INTERNAL REVENUE SERVICE: 1
# T AND T CONSULTING SERVICES, INC. -> NATIONAL OFFICE - PROCUREMENT OITA: 2
